# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 가우시안 분포에서 측정값 생성
x = np.arange(0, 10, 1)

# "측정된" 값을 계산한 것
y = np.log(x)

# 표준 정규 분포에서 일부 오차 샘플 추가
xe = 0.1 * np.abs(np.random.randn(len(y)))

# 오차 막대 그리기 및 표시
plt.bar(x, y, yerr=xe, width=0.4, align='center', ecolor='r', color='cyan',
                                                    label='experiment #1');

# 설명 추가
plt.xlabel('# measurement')
plt.ylabel('Measured values')
plt.title('Measurements')
plt.legend(loc='upper left')

plt.show()
# Out:
# C:\Users\aweso\AppData\Local\Temp\ipykernel_6564\3100738203.py:5: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
