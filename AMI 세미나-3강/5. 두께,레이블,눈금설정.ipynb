# %%
from pylab import *

# %%
# 현재 축 가져오기
ax = gca()

# 보기를 tight하게 설정하고 최대 눈금 간격을 10으로 설정
ax.locator_params(tight=True, nbins=10)

# 100개의 정규 분포 값을 생성
ax.plot(np.random.normal(10, .1, 100))

show()

# %%
import matplotlib as mpl
import datetime

# %%
fig = figure()

# 현재 축 가져오기
ax = gca()

# 일부 날짜 범위 설정
start = datetime.datetime(2013, 1, 1)
stop = datetime.datetime(2013, 12, 31)
delta = datetime.timedelta(days=1)

# 날짜를 matplotlib 형식으로 변환
dates = mpl.dates.drange(start, stop, delta)

# 임의의 값 생성
values = np.random.rand(len(dates))

# 날짜를 포함한 그래프 생성
ax.plot_date(dates, values, linestyle='-', marker='')

# 포맷터 지정
date_format = mpl.dates.DateFormatter('%Y-%m-%d')

# 포맷터 적용
ax.xaxis.set_major_formatter(date_format)

# 날짜 라벨을 자동으로 포맷팅
# 기본값은 레이블을 30도 회전
# 회전 매개변수를 사용하여 다른 회전 각도 지정
# 하단 매개변수를 사용해 더 많은 공간을 날짜 레이블로 지정
fig.autofmt_xdate()

show()
# Out:
# C:\Users\aweso\AppData\Local\Temp\ipykernel_24128\1918087045.py:18: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(dates, values, linestyle='-', marker='')
