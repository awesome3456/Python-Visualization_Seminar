# %%
from matplotlib.pylab import *

# %%
from matplotlib.pylab import *

print(axis())
axis([-1, 1, -10, 10])
print(axis())
axhline()
axhline()
axhline(4)
axvline(0.0)
show()
# Out:
# (0.0, 1.0, 0.0, 1.0)
# (-1.0, 1.0, -10.0, 10.0)
