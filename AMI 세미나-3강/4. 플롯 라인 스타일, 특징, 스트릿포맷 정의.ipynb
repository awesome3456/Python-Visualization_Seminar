# %%
from matplotlib.pyplot import *

# %%
from matplotlib.pyplot import *

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plot(x, y, linewidth=1.5)
show()

# %%
lines = plot(x, y, linestyle='--', linewidth=1.5)

# %%
lines = plot(x, y)
setp(lines, linewidth=1.5)
setp(lines, linestyle='-', marker='o', markersize=10, markerfacecolor='red', markeredgewidth=2, markeredgecolor='blue')
# Out:
# [None, None, None, None, None, None]
